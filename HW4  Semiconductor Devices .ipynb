# %%
import numpy as np
import matplotlib.pyplot as plt

SMALL_SIZE = 30
MEDIUM_SIZE = 35
BIGGER_SIZE = 45

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
#plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

plt.rcParams.update({'font.size': 22})

# %%
c = 3*10**8 #speed of light (m/s)
wl = 405*10**-9 #wavelenght (m)

# %%
def lin(x): #linear relation
    return 3.4-2.8*x

# %%
t= np.arange(0, 1, 10**-4)

plt.figure( figsize=(19,10) )
plt.plot(t, lin(t), color = 'r', label = 'Linear dependence of the bandgap of In$_x$Ga$_{1-x}$N')
plt.axvline(x = 0.13, c= 'k',ls ="--", label = 'Composition of InGaN quoted in the paper')
plt.plot(0.13, lin(0.13), 'o', color = 'k', label = 'Bandgap energy of In$_{0.13}$Ga$_{0.87}$N quoted in the paper')
plt.annotate(text = '(0.13, 3.036)', xy = (0.13, 3.036), xytext=(0.14, 3.1))
plt.legend(loc='best')
plt.xlabel('$x$')
plt.ylabel('$Energy \ (eV)$')
plt.savefig('linear relation.jpeg', dpi=300, bbox_inches='tight')

# %%
A = 2*10**8
B = 10**-10
C = 2.7*10**-30

def IQE(n):
    return B*n**2/(A*n + B*n**2 + C*n**3)

# %%
t = np.arange(10**17, 5*10**19, 10**15)

plt.figure( figsize=(19,10) )
plt.plot(t, IQE(t), color = 'r')
plt.xlabel('$n \ (cm^{-3})$')
plt.ylabel('$IQE$')
plt.savefig('IQE.jpeg', dpi=300, bbox_inches='tight')
